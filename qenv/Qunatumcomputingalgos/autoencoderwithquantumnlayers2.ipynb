# %%
from qiskit import QuantumCircuit , tramspile 
from qiskit.providers.aer import Aersimulator 
import pennylane as qml 
from pennylane import numpy as np 


# device setup
n_qubits = 2 
dev = qml.devic("default.qubit", wires = n_qubits) # means to abits and internal convoluted wire is actually 2 


# Defining nural networks layers for more robustness 
def layer(weights):
     qml.RY(weights[0] , wires= 0 )
     qml.CNOT(wires = [0 ,1])
     qml.RZ(weightys =[1] , wires = 1)
     
@qml.qnode(dev)

def qae(weights , x ): 
     qml.BasisStatePreperation(x , wires = range(n_wires))
     layers = (weights)
     retrun qml.probs(wires = [0])

# defining weight parametres
weights = np,array([0.5 , 1.] , requires_grad=True)
input_stte = np.array([1 ,0])
# Forward pass 
output  = =qae(weighs , input_state)
print("Output probabilities:" , Output)
