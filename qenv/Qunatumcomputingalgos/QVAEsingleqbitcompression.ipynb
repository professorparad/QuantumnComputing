# %%
from qiskit import QuantumCircuit , tramspile 
from qiskit.providers.aer import Aersimulator 

## Define auto encoder 

qc = QuantumCircuit(2 ,1)

## Inout preparation(state encoding)
qc.h(0)# hadamard gate encode info
qc.cx(0,1)

## Compression(removing redundancy)
qc.reset(1) # compression (Reset qbit 1 tp |0>)

# Recompression(inverse operation )
qc.cx(0,1)
q.h(0)

#Measurement 
qc.measure(0,0)
#simulate the circuit 
sim= Aersimulator()
compiled_circuit = transpile(qc , sim)
result = sim.run(compiled_circuit).result()
counts = result.get_count()

print("QAE Output state:*, counts)
